# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/91798/Downloads/Sales_Data.csv',encoding = 'unicode_escape')

# %%
df.shape #It shows no.of colums(15) and rows(11251) in csv file
# Out:
# (11251, 15)

# %%
df.head(10) #show details of csv
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info() #Shows information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# **To Clean the data which having null data i.e. col_no. 13,14**

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True) #Status and unnamed1 are column names
#axis=1 refers the complete vertical row in dataset                                                    
# inplace=True indicates that this line should implement and savi it

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df) # To check null values
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum() #here sum() is used to count the null values in dataset(i.e.amount column has 12)
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape # rows = 11251(including rows containing null values), cols=13
# Out:
# (11251, 13)

# %%
#To drop null values
df.dropna(inplace=True)

# %%
df.shape #after deleting null values,rows=11239 and cols=13
# Out:
# (11239, 13)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# __Example to show use of inplace__

# %%
# Intialize list of lists
data_test = [['Neha',20,'London'],['Harsha',19,'USA'],['Sony', ],['John',16,'Canada']]

# Create the pandas Dataframe using list
df_test = pd.DataFrame(data_test, columns=['Name','Age','Country'])

df_test #Sony having null values
# Out:
#      Name   Age Country
# 0    Neha  20.0  London
# 1  Harsha  19.0     USA
# 2    Sony   NaN    None
# 3    John  16.0  Canada

# %%
df_test.dropna() #Dropped null valued row i.e. 2nd row
# Out:
#      Name   Age Country
# 0    Neha  20.0  London
# 1  Harsha  19.0     USA
# 3    John  16.0  Canada

# %%
df_test #But when we run again It will give the old values(including null valued row)
# Out:
#      Name   Age Country
# 0    Neha  20.0  London
# 1  Harsha  19.0     USA
# 2    Sony   NaN    None
# 3    John  16.0  Canada

# %%
#We can solve this issue by assigning to another variable to store the deleted null valued row(i.e. 2) details.
# But using this creates another memory location(i.e. Wastage of memory)
df_test1 = df_test.dropna()

# %%
df_test1
# Out:
#      Name   Age Country
# 0    Neha  20.0  London
# 1  Harsha  19.0     USA
# 3    John  16.0  Canada

# %%
#To solve this issue we will use the inplace=True(To save the details)
df_test.dropna(inplace=True)

# %%
df_test #here we can see that there is no 2nd row
# Out:
#      Name   Age Country
# 0    Neha  20.0  London
# 1  Harsha  19.0     USA
# 3    John  16.0  Canada

# %% [markdown]
# __Changing Datatype of specific column.__

# %%
# Changing datatype of Amount(float64) to int32
df['Amount'] = df['Amount'].astype('int') #astype() method is used to change datatype

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
#To get the columns in dataset
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#Rename the column using rename() and dictionary
df.rename(columns = {'Marital_Status':'Civil_Status'},inplace=True)

# %%
df.head(3)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Civil_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28             0
# 1  1000732     Kartik  P00110942      F     26-35   35             1
# 2  1001990      Bindu  P00118542      F     26-35   35             1
#
#             State      Zone  Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western  Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern        Govt             Auto       3   23934
# 2   Uttar Pradesh   Central  Automobile             Auto       3   23924

# %%
# describe() method used to return description of the data in the DataFrame(i.e. count,mean,std(standard deviation),etc)
df.describe()
# Out:
#             User_ID           Age  Civil_Status        Orders        Amount
# count  1.123900e+04  11239.000000  11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357      0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866      0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000      0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000      1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Civil_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ### countplot()
# **method is used to Show the counts of observations in each categorical bin using bars.**

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars) # "ax.bar_label()" function is used to add value labels(like 7832 on female bar and 3407 on male bar) to the bars in the bar plot.

# %% [markdown]
# ## groupby()
#
# * __groupby() function is used to split the data into groups based on some criteria__
#
# __Syntax:__
#
# _DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True)_
#
# * __as_index :__ For aggregated output, __return object with group labels as the index.__ Only relevant for DataFrame input. __as_index=False is effectively “SQL-style” grouped output__
#
# ## sort_values()
#
# * __sort_values() function sorts a data frame in Ascending or Descending order of passed Column.__
#
# __Syntax:__
#
# _DataFrame.sort_values(by,ascending=True,)_
#
# __by:__ Single/List of column names to sort Data Frame by.
# __ascending:__ Boolean value which sorts Data frame in ascending order if True.

# %%
sales_gen = df.groupby(['Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending=False)

sns.barplot(x = 'Gender', y = 'Amount', data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are Females and even the purchasing power of Females are greater than men

# %% [markdown]
# ## Age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Civil_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
bx = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in bx.containers:
    bx.bar_label(bars)

# %%
# Total Amount vs Age Group

sales_age = df.groupby(['Age Group'],as_index = False)['Amount'].sum().sort_values(by = 'Amount',ascending = False)

sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are of age group between 26-35 yrs Female

# %% [markdown]
# ## State

# %%
# Total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(25,15)})
sns.barplot(data = sales_state, x = 'State', y = 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# Total Amount/Sales from top 10 states

sales_state = df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(25,15)})
sns.barplot(data = sales_state, x = 'State', y = 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# ## Marital Status

# %%
ax = sns.countplot(data = df, x = 'Civil_Status')

sns.set(rc = {'figure.figsize':(7,5)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Civil_Status', 'Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)

sns.set(rc = {'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Civil_Status', y = 'Amount', hue = 'Gender')
# Out:
# <Axes: xlabel='Civil_Status', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# ## Occupation

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Civil_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Occupation')
sns.set(rc={'figure.figsize':(20,5)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector.

# %% [markdown]
# ## Product Category

# %%
ax = sns.countplot(data = df, x = 'Product_Category')
sns.set(rc = {'figure.figsize':(28,10)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %% [markdown]
# ## Product Id

# %%
# Top 10 most sold products (same thing as above)
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(12,7)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # Conclusion
#
# ### Married women age group 26-35 yrs from Uttar Pradesh, Maharastra and Karnataka working in IT, Healthcare and Aviation sectors are more likely to buy products from Food, Clothing and Electronics category.
